# %%
import requests

# URL of the Flask backend
url = "http://127.0.0.1:5000/predict"  # Adjust route if needed

# Sample input data as a dictionary (match your model input format!)
data = {
    "LDA_PARTNUMBER": "5443"  # <-- Replace this with actual input keys/values
}

# Make the POST request
res = requests.post(url, json=data)

# Print the result
print("Status Code:", res.status_code)
print("Raw Response Text:", res.text)

# Try to print JSON if valid
try:
    print("Prediction Response (JSON):", res.json())
except Exception as e:
    print("Failed to decode JSON:", e)
# Out:
# Status Code: 404
# Raw Response Text: <HTML><HEAD>
# 			<TITLE>Web Site does not exist</TITLE>
# 			<link rel="shortcut icon" href="https://rbins.bosch.com/gfx/favicon.ico">
# 			<link rel="stylesheet" href="https://rbins.bosch.com/gfx/styles.css">
# 		</HEAD>
# 		<BODY>
# 		    <table>
# 		        <TR>
# 		            <td width="128" ><img height=31 src=https://rbins.bosch.com/gfx/bosch_logo.png alt=BOSCH></td>
# 				    <td width="700" align="center"><h1 class="errorsum_header">Web Site does not exist</h1></td>
# 		        </TR>
# 		        <TR>
# 		            <TD width="128"></TD>
# ...
